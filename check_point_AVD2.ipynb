# %% [markdown]
# # Library

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/WLD_RTFP_country_2023-10-02.csv')
df
# Out:
#       Open  High   Low  Close  Inflation      country ISO3        date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...         ...
# 4793  2.74  2.78  2.70   2.75      -0.28  Yemen, Rep.  YEM  2023-06-01
# 4794  2.79  2.83  2.75   2.81      -1.85  Yemen, Rep.  YEM  2023-07-01
# 4795  2.85  2.89  2.81   2.83      -3.17  Yemen, Rep.  YEM  2023-08-01
# 4796  2.86  2.97  2.82   2.97       1.68  Yemen, Rep.  YEM  2023-09-01
# 4797  3.06  3.11  2.98   2.98       3.76  Yemen, Rep.  YEM  2023-10-01
#
# [4798 rows x 8 columns]

# %% [markdown]
# # Data Understanding

# %% [markdown]
# Sumber data yang saya gunakan dalam analisis ini berasal dari kaggle yaitu Laptop Price Prediction cleaned Dataset (https://www.kaggle.com/datasets/gyanprakashkushwaha/laptop-price-prediction-cleaned-dataset)

# %% [markdown]
# # Struktur Dan Tipe data

# %%
print("Menampilkan Beberapa Row Data:")
df.head(12)
# Out:
# Menampilkan Beberapa Row Data:
#     Open  High   Low  Close  Inflation      country ISO3        date
# 0   0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01
# 1   0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01
# 2   0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01
# 3   0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01
# 4   0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01
# 5   0.59  0.60  0.58   0.58        NaN  Afghanistan  AFG  2007-06-01
# 6   0.59  0.60  0.59   0.59        NaN  Afghanistan  AFG  2007-07-01
# 7   0.60  0.60  0.59   0.59        NaN  Afghanistan  AFG  2007-08-01
# 8   0.60  0.62  0.59   0.62        NaN  Afghanistan  AFG  2007-09-01
# 9   0.64  0.64  0.63   0.63        NaN  Afghanistan  AFG  2007-10-01
# 10  0.65  0.66  0.64   0.66        NaN  Afghanistan  AFG  2007-11-01
# 11  0.68  0.71  0.67   0.71        NaN  Afghanistan  AFG  2007-12-01

# %% [markdown]
# # Jumlah kolom dan baris

# %%
print("Menampilkan tipe data pada setiap kolom:")
df.dtypes
# Out:
# Menampilkan tipe data pada setiap kolom:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Inflation    float64
# country       object
# ISO3          object
# date          object
# dtype: object

# %% [markdown]
# # Jumlah dan kolom baris

# %%
print("menampikan jumlah kolom dan baris")

df.shape
# Out:
# menampikan jumlah kolom dan baris
# (4798, 8)

# %% [markdown]
# # Statistik dan Deksriptif

# %%
print("\nMenampilkan statistik deskriptif:")
df.describe()
# Out:
# Menampilkan statistik deskriptif:
#               Open         High          Low        Close    Inflation
# count  4734.000000  4734.000000  4734.000000  4734.000000  4434.000000
# mean      1.491880     1.536158     1.451056     1.492398    14.692346
# std       4.652457     4.883312     4.439229     4.633321    35.910342
# min       0.010000     0.010000     0.010000     0.010000   -31.470000
# 25%       0.740000     0.750000     0.720000     0.740000    -0.487500
# 50%       0.960000     0.980000     0.950000     0.960000     5.360000
# 75%       1.100000     1.120000     1.077500     1.100000    16.372500
# max     102.460000   106.480000    94.420000    94.420000   363.100000

# %%
print("\nMenghitung rata-rata:")
df.mean(numeric_only=True)
# Out:
# Menghitung rata-rata:
# Open          1.491880
# High          1.536158
# Low           1.451056
# Close         1.492398
# Inflation    14.692346
# dtype: float64

# %%
print("\nMenghitung median:")
df.median(numeric_only=True)
# Out:
# Menghitung median:
# Open         0.96
# High         0.98
# Low          0.95
# Close        0.96
# Inflation    5.36
# dtype: float64

# %%
print("\nMenghitung standar deviasi:")
df.std(numeric_only=True)
# Out:
# Menghitung standar deviasi:
# Open          4.652457
# High          4.883312
# Low           4.439229
# Close         4.633321
# Inflation    35.910342
# dtype: float64

# %%
print("\nMenghitung korelasi antar kolom numerik:")
df.corr(numeric_only=True)
# Out:
# Menghitung korelasi antar kolom numerik:
#                Open      High       Low     Close  Inflation
# Open       1.000000  0.998958  0.999731  0.997202   0.362280
# High       0.998958  1.000000  0.998734  0.998961   0.362110
# Low        0.999731  0.998734  1.000000  0.997874   0.363067
# Close      0.997202  0.998961  0.997874  1.000000   0.364800
# Inflation  0.362280  0.362110  0.363067  0.364800   1.000000

# %% [markdown]
# # Data Preparation

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/WLD_RTFP_country_2023-10-02.csv')
df
# Out:
#       Open  High   Low  Close  Inflation      country ISO3        date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...         ...
# 4793  2.74  2.78  2.70   2.75      -0.28  Yemen, Rep.  YEM  2023-06-01
# 4794  2.79  2.83  2.75   2.81      -1.85  Yemen, Rep.  YEM  2023-07-01
# 4795  2.85  2.89  2.81   2.83      -3.17  Yemen, Rep.  YEM  2023-08-01
# 4796  2.86  2.97  2.82   2.97       1.68  Yemen, Rep.  YEM  2023-09-01
# 4797  3.06  3.11  2.98   2.98       3.76  Yemen, Rep.  YEM  2023-10-01
#
# [4798 rows x 8 columns]

# %% [markdown]
# # Missing Values

# %% [markdown]
# pada tahap ini dilakukan pengecekan terhadap data yang hilang dalam setiap kolom dalam bentuk presentase.

# %%
print("Menampilkan missing values:")
(df.isna().sum() / len(df)) * 100
# Out:
# Menampilkan missing values:
# Open         1.333889
# High         1.333889
# Low          1.333889
# Close        1.333889
# Inflation    7.586494
# country      0.000000
# ISO3         0.000000
# date         0.000000
# dtype: float64

# %%
df[df['Open'].isnull()]
# Out:
#       Open  High  Low  Close  Inflation   country ISO3        date
# 808    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-01-01
# 809    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-02-01
# 810    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-03-01
# 811    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-04-01
# 812    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-05-01
# ...    ...   ...  ...    ...        ...       ...  ...         ...
# 2134   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-09-01
# 2135   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-10-01
# 2136   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-11-01
# 2137   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-12-01
# 2138   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2009-01-01
#
# [64 rows x 8 columns]

# %%
df[df['High'].isnull()]
# Out:
#       Open  High  Low  Close  Inflation   country ISO3        date
# 808    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-01-01
# 809    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-02-01
# 810    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-03-01
# 811    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-04-01
# 812    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-05-01
# ...    ...   ...  ...    ...        ...       ...  ...         ...
# 2134   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-09-01
# 2135   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-10-01
# 2136   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-11-01
# 2137   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-12-01
# 2138   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2009-01-01
#
# [64 rows x 8 columns]

# %%
df[df['Low'].isnull()]
# Out:
#       Open  High  Low  Close  Inflation   country ISO3        date
# 808    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-01-01
# 809    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-02-01
# 810    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-03-01
# 811    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-04-01
# 812    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-05-01
# ...    ...   ...  ...    ...        ...       ...  ...         ...
# 2134   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-09-01
# 2135   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-10-01
# 2136   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-11-01
# 2137   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-12-01
# 2138   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2009-01-01
#
# [64 rows x 8 columns]

# %%
df[df['Close'].isnull()]
# Out:
#       Open  High  Low  Close  Inflation   country ISO3        date
# 808    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-01-01
# 809    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-02-01
# 810    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-03-01
# 811    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-04-01
# 812    NaN   NaN  NaN    NaN        NaN  Cameroon  CMR  2007-05-01
# ...    ...   ...  ...    ...        ...       ...  ...         ...
# 2134   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-09-01
# 2135   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-10-01
# 2136   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-11-01
# 2137   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2008-12-01
# 2138   NaN   NaN  NaN    NaN        NaN   Lao PDR  LAO  2009-01-01
#
# [64 rows x 8 columns]

# %%
df[df['Inflation'].isnull()]
# Out:
#       Open  High   Low  Close  Inflation      country ISO3        date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...         ...
# 4627  0.51  0.52  0.51   0.51        NaN  Yemen, Rep.  YEM  2009-08-01
# 4628  0.51  0.52  0.50   0.51        NaN  Yemen, Rep.  YEM  2009-09-01
# 4629  0.52  0.53  0.52   0.53        NaN  Yemen, Rep.  YEM  2009-10-01
# 4630  0.53  0.54  0.52   0.53        NaN  Yemen, Rep.  YEM  2009-11-01
# 4631  0.54  0.54  0.53   0.53        NaN  Yemen, Rep.  YEM  2009-12-01
#
# [364 rows x 8 columns]

# %% [markdown]
# # Melakukan Imputasi

# %% [markdown]
# saya akan melakukan imputasi pada beberapa kolom, yaitu Open, Low, . Proses imputasi dilakukan karena data yang hilang pada kolom-kolom tersebut berada di bawah ambang batas 70%, sehingga memungkinkan untuk diisi menggunakan teknik seperti mean, median, atau modus.

# %% [markdown]
# Imputasi kolom Open

# %%
df['Open'].dropna().describe()
# Out:
# count    4734.000000
# mean        1.491880
# std         4.652457
# min         0.010000
# 25%         0.740000
# 50%         0.960000
# 75%         1.100000
# max       102.460000
# Name: Open, dtype: float64

# %%
mean_value = df['Open'].dropna().mean()
df['Open'] = df['Open'].fillna(int(mean_value))

# %% [markdown]
# Melakukan imputasi pada kolom High

# %%
df['High'].dropna().describe()
# Out:
# count    4734.000000
# mean        1.536158
# std         4.883312
# min         0.010000
# 25%         0.750000
# 50%         0.980000
# 75%         1.120000
# max       106.480000
# Name: High, dtype: float64

# %%
df['High'] = df['Low'].fillna(df['Low'].dropna().mean())

# %% [markdown]
# Imputasi kolom Low

# %%
df['Low'].dropna().describe()
# Out:
# count    4734.000000
# mean        1.451056
# std         4.439229
# min         0.010000
# 25%         0.720000
# 50%         0.950000
# 75%         1.077500
# max        94.420000
# Name: Low, dtype: float64

# %%
df['Low'] = df['Low'].fillna(df['Low'].dropna().mean())

# %% [markdown]
# imputasi pada kolom Close

# %%
df['Close'].dropna().describe()
# Out:
# count    4734.000000
# mean        1.492398
# std         4.633321
# min         0.010000
# 25%         0.740000
# 50%         0.960000
# 75%         1.100000
# max        94.420000
# Name: Close, dtype: float64

# %%
df['Close'] = df['Close'].fillna(df['Close'].dropna().mean())

# %% [markdown]
# imputasi pada kolom Inflation

# %%
df['Inflation'].dropna().describe()
# Out:
# count    4434.000000
# mean       14.692346
# std        35.910342
# min       -31.470000
# 25%        -0.487500
# 50%         5.360000
# 75%        16.372500
# max       363.100000
# Name: Inflation, dtype: float64

# %%
df['Inflation'] = df['Inflation'].fillna(df['Inflation'].dropna().mean())

# %% [markdown]
# # Duplikat

# %%
print("Jumlah data duplikat:", df.duplicated().sum())
# Out:
# Jumlah data duplikat: 0

# %%
print("Menampilkan dupilcated values:")
df[df.duplicated()]
# Out:
# Menampilkan dupilcated values:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Inflation, country, ISO3, date]
# Index: []

# %% [markdown]
# #Outliers

# %%
print("Pengecekan outliers:")

results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Pengecekan outliers:
# Kolom      Persentase Outliers
# Open                 11.025427
# High                 10.650271
# Low                  10.650271
# Close                10.712797
# Inflation            10.421009

# %%
df
# Out:
#       Open  High   Low  Close  Inflation      country ISO3        date
# 0     0.53  0.53  0.53   0.53  14.692346  Afghanistan  AFG  2007-01-01
# 1     0.53  0.53  0.53   0.53  14.692346  Afghanistan  AFG  2007-02-01
# 2     0.54  0.53  0.53   0.53  14.692346  Afghanistan  AFG  2007-03-01
# 3     0.53  0.53  0.53   0.55  14.692346  Afghanistan  AFG  2007-04-01
# 4     0.56  0.56  0.56   0.57  14.692346  Afghanistan  AFG  2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...         ...
# 4793  2.74  2.70  2.70   2.75  -0.280000  Yemen, Rep.  YEM  2023-06-01
# 4794  2.79  2.75  2.75   2.81  -1.850000  Yemen, Rep.  YEM  2023-07-01
# 4795  2.85  2.81  2.81   2.83  -3.170000  Yemen, Rep.  YEM  2023-08-01
# 4796  2.86  2.82  2.82   2.97   1.680000  Yemen, Rep.  YEM  2023-09-01
# 4797  3.06  2.98  2.98   2.98   3.760000  Yemen, Rep.  YEM  2023-10-01
#
# [4798 rows x 8 columns]

# %% [markdown]
# # Iconsistent values

# %%
df
# Out:
#        Open  High   Low  Close  Inflation      country ISO3        date  \
# 0     0.530  0.53  0.53  0.530  14.692346  Afghanistan  AFG  2007-01-01
# 1     0.530  0.53  0.53  0.530  14.692346  Afghanistan  AFG  2007-02-01
# 2     0.540  0.53  0.53  0.530  14.692346  Afghanistan  AFG  2007-03-01
# 3     0.530  0.53  0.53  0.550  14.692346  Afghanistan  AFG  2007-04-01
# 4     0.560  0.56  0.56  0.570  14.692346  Afghanistan  AFG  2007-05-01
# ...     ...   ...   ...    ...        ...          ...  ...         ...
# 4793  1.615  1.63  1.63  1.665  -0.280000  Yemen, Rep.  YEM  2023-06-01
# 4794  1.615  1.63  1.63  1.665  -1.850000  Yemen, Rep.  YEM  2023-07-01
# 4795  1.615  1.63  1.63  1.665  -3.170000  Yemen, Rep.  YEM  2023-08-01
# 4796  1.615  1.63  1.63  1.665   1.680000  Yemen, Rep.  YEM  2023-09-01
# 4797  1.615  1.63  1.63  1.665   3.760000  Yemen, Rep.  YEM  2023-10-01
#
#      Price_change  Price_Change  Close_MA_3  Close_MA_6 price_change
# ...

# %%
print(df.isnull().sum())
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Inflation       0
# country         0
# ISO3            0
# date            0
# Price_change    0
# Price_Change    1
# Close_MA_3      2
# Close_MA_6      5
# price_change    0
# dtype: int64

# %% [markdown]
# dikarenakan tidak ada missing values maka saya tidak perlu melakukan imputasi

# %% [markdown]
# # Construct Data

# %% [markdown]
# saya menggunakan price_change untuk menghitung perubahan presesentase harga apakah berubah tiap tahunnya

# %%
df["Price_Changes"] = df["Close"].apply(lambda x: "Yes" if x > 700 else "No")

print(df.head())
# Out:
#    Open  High   Low  Close  Inflation      country ISO3        date  \
# 0  0.53  0.53  0.53   0.53  14.692346  Afghanistan  AFG  2007-01-01
# 1  0.53  0.53  0.53   0.53  14.692346  Afghanistan  AFG  2007-02-01
# 2  0.54  0.53  0.53   0.53  14.692346  Afghanistan  AFG  2007-03-01
# 3  0.53  0.53  0.53   0.55  14.692346  Afghanistan  AFG  2007-04-01
# 4  0.56  0.56  0.56   0.57  14.692346  Afghanistan  AFG  2007-05-01
#
#   Price_change  Price_Change  Close_MA_3  Close_MA_6 price_change  \
# 0           No           NaN         NaN         NaN           No
# 1           No      0.000000         NaN         NaN           No
# 2           No      0.000000    0.530000         NaN           No
# 3           No      3.773585    0.536667         NaN           No
# 4           No      3.636364    0.550000         NaN           No
#
#   Price_Changes
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No

# %%
df
# Out:
#        Open  High   Low  Close  Inflation      country ISO3        date  \
# 0     0.530  0.53  0.53  0.530  14.692346  Afghanistan  AFG  2007-01-01
# 1     0.530  0.53  0.53  0.530  14.692346  Afghanistan  AFG  2007-02-01
# 2     0.540  0.53  0.53  0.530  14.692346  Afghanistan  AFG  2007-03-01
# 3     0.530  0.53  0.53  0.550  14.692346  Afghanistan  AFG  2007-04-01
# 4     0.560  0.56  0.56  0.570  14.692346  Afghanistan  AFG  2007-05-01
# ...     ...   ...   ...    ...        ...          ...  ...         ...
# 4793  1.615  1.63  1.63  1.665  -0.280000  Yemen, Rep.  YEM  2023-06-01
# 4794  1.615  1.63  1.63  1.665  -1.850000  Yemen, Rep.  YEM  2023-07-01
# 4795  1.615  1.63  1.63  1.665  -3.170000  Yemen, Rep.  YEM  2023-08-01
# 4796  1.615  1.63  1.63  1.665   1.680000  Yemen, Rep.  YEM  2023-09-01
# 4797  1.615  1.63  1.63  1.665   3.760000  Yemen, Rep.  YEM  2023-10-01
#
#      Price_change  Price_Change  Close_MA_3  Close_MA_6 price_change  \
# ...

# %% [markdown]
# # Data reduction

# %%
df = df.drop('Price_Changes', axis=1)

# %%
df
# Out:
#        Open  High   Low  Close  Inflation      country ISO3        date  \
# 0     0.530  0.53  0.53  0.530  14.692346  Afghanistan  AFG  2007-01-01
# 1     0.530  0.53  0.53  0.530  14.692346  Afghanistan  AFG  2007-02-01
# 2     0.540  0.53  0.53  0.530  14.692346  Afghanistan  AFG  2007-03-01
# 3     0.530  0.53  0.53  0.550  14.692346  Afghanistan  AFG  2007-04-01
# 4     0.560  0.56  0.56  0.570  14.692346  Afghanistan  AFG  2007-05-01
# ...     ...   ...   ...    ...        ...          ...  ...         ...
# 4793  1.615  1.63  1.63  1.665  -0.280000  Yemen, Rep.  YEM  2023-06-01
# 4794  1.615  1.63  1.63  1.665  -1.850000  Yemen, Rep.  YEM  2023-07-01
# 4795  1.615  1.63  1.63  1.665  -3.170000  Yemen, Rep.  YEM  2023-08-01
# 4796  1.615  1.63  1.63  1.665   1.680000  Yemen, Rep.  YEM  2023-09-01
# 4797  1.615  1.63  1.63  1.665   3.760000  Yemen, Rep.  YEM  2023-10-01
#
#      Price_change  Price_Change  Close_MA_3  Close_MA_6 price_change
# ...
